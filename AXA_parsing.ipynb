# %% [markdown]
# ## Парсер

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options

# %%
import time
import numpy as np
from tqdm import tqdm

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
chrome_options = Options()  
chrome_options.add_argument("--headless")  
chrome_options.add_argument("--start-maximized")
chrome_options.add_argument("--start-fullscreen")
chrome_options.add_argument("--no-proxy-server")
chrome_options.add_argument("--proxy-server='direct://'")
chrome_options.add_argument("--proxy-bypass-list=*")

# %%
gen_info = [] ### Этот код для того того, чтобы получить ссылки на страницу каждого университета на сайте
url = 'https://www.topuniversities.com/university-rankings/world-university-rankings/2023?qs_qp=topnav'

### И еще важно, чтобы код проработал нормально, окно браузера должно быть полностью открыто. 


with webdriver.Chrome() as browser:
    browser.get(url) ### это главная страница, на которой находятся все ссылки
    browser.maximize_window()
    time.sleep(1)
    
    ### На странице представлено более 1000 университетов. При этом на данный момент в html коде видна инфа только по 10 университетам.
    ### Чтобы это исправить, надо увеличить диапозов видимых университетов до 100. Так будет быстрее
    
    ### В коде ниже мы находим необходимый dropdown, после чего прокручиваем для него страницу. Scrollby как костыль, потому что 
    ### на моем мониторе кнопку после скроллинга перекрывало меню, из-за чего я чутка прокручиваю страницу на вверх
    ### Кстати, к проверяющему: если активируйте код, то, возможно, скроллинга в -100 будет не хватать (или будет слишком много)
    ### Из-за чего кнопка будет не видная и на нее не нажмешь. Нужно будет этот момент проследить.
    change_name = browser.find_elements(By.XPATH, "//div[@class = 'ui fluid  selection dropdown _semantic_select newzindex sort_by_dropdown perpage_dropdown_js inline-block minwidth84 pull-left margin-right-px']")[-1]
    browser.execute_script("return arguments[0].scrollIntoView(true);", change_name)
    browser.execute_script("window.scrollBy(0,-100)")
    change_name.click()
    time.sleep(1)
    
    ### Тут жмем на кнопку и получаем дисплей на 100 университетов
    
    button_100 = browser.find_element(By.XPATH, "//div[@class = 'menu transition visible']/div[4]")
    button_100.click()
    
    time.sleep(10)
    
    ### тут сохраняем кнопочку, на которую нажимаем, когда хотим получить следующие 100 университетов
    button = WebDriverWait(browser, 20).until(EC.element_to_be_clickable((By.XPATH, "//a[@class = 'page-link next']")))
    print(button.location)
    
    ### Сделал while, так как в рейтинге у нас 1420 университетов
    while len(gen_info) < 1420:
        
        
        names_links = browser.find_elements(By.CLASS_NAME, 'uni-link') ### Тут узел, создержаштй ссылки
        
        
        names = [i.text for i in names_links] ### Тут имена вузов
        
        rank = [i.text for i in browser.find_elements(By.XPATH, "//div[@class = '_univ-rank hide-this-in-mobile-indi ']")] # позиция
        ### вуза в рейтинге
        
        links = [i.get_attribute('href') for i in names_links] ### Тут уже непосредственно сами ссылки
        
        locations = [i.text for i in browser.find_elements(By.CLASS_NAME, 'location')] ### тут местоположение вуза
        
        ### Здесь итоговые баллые в рейтинге
        points = [i.text for i in browser.find_elements(By.XPATH, "//span[@class = 'overall-score-span hide-this-in-mobile-indi']")] 
        
        first_info = list(zip(rank,names,links,locations,points)) ### тут собираем всю инфу в один tuple
        
        gen_info.extend(first_info) ### и добавляем в общий пул с другими университетами
        
        print(first_info)
        
    
        
        
        ### Тут на всякий пожарный еще рас сохраняю кнопку для нахождения вуза. Когда дойдет до 1420, то кнопка не будет clickable.
        ### Честно, когда комментарии писал - задумался, зачем тут этот трай, но до конца не пойму. Видимо, у меня была какая-то
        ### глубока мысль, из-за которой я решил это использовать
        
        try: 
            button = WebDriverWait(browser, 20).until(EC.element_to_be_clickable((By.XPATH, "//a[@class = 'page-link next']")))
        except Exception:
            print('Спарсили, мэл')
            break

        browser.execute_script("return arguments[0].scrollIntoView(true);", button)
        browser.execute_script("window.scrollBy(0,-200)")
        time.sleep(10)
        
        button.click()

# %%
data = pd.DataFrame(gen_info, columns=['rank', 'name', 'link', 'location','points'])

# %%
circle_dict = {}
student_stats_dict = {}

did_not_work = {}


### Тут все более прозаично. Много траев, чтобы из-за одной неспарсенной ячейки код не ломался, а если будет ошибка,
### то будем знать где. Кстати, суммарно парсилось долго.

with webdriver.Chrome(options=chrome_options) as browser:
    browser.get(url1)
    browser.maximize_window()
    for i,j in tqdm(list(zip(data['link'].values, data['name'].values))):
        
        ### Заходим на страничку сайта
        try:
            browser.get(i)
        except Exception:
            print('Страница не загрузилась')
            print(j)
            did_not_work.setdefault(j,i)
            continue
         
        ### Ждеем пока прогрузиться локация (эмпирически выяснил, что если локация прогрузилась, то прогрузилась и вся остальная инфа)
        try:
        
            WebDriverWait(browser, 20).until(EC.presence_of_element_located((By.CLASS_NAME, 'circle')))
            
            ### Тут оценки по 100 шкале за различные показатели
            circles = [tuple(i.text.split('\n')) for i in browser.find_elements(By.CLASS_NAME, 'circle')]
            circle_dict.setdefault(j,circles)
        except Exception:
            print('Затупил на кружочках')
            print(j)
            did_not_work.setdefault(j,i)
            continue
            
        try:   
            ### Тут количество работяг в вузе (то есть преподавателей). Но там опять надо жмыкнуть на кнопку, чтобы найти всю инфу
            stud_staff_but = browser.find_element(By.ID, 'studStaff_Tab')
            browser.execute_script("return arguments[0].scrollIntoView(true);", stud_staff_but)
            browser.execute_script("window.scrollBy(0,-400)")
            stud_staff_but.click()
        except Exception:
            print('Затупил с кнопкой')
            print(j)
            did_not_work.setdefault(j,i)
            continue
        
        try:
            ### Тут уже получаем инфу по количеству студентов.
            WebDriverWait(browser,20).until(EC.visibility_of_all_elements_located((By.CLASS_NAME, 'studstaff-subsection-title')))
            WebDriverWait(browser,20).until(EC.visibility_of_all_elements_located((By.CLASS_NAME, 'studstaff-subsection-count')))
            stats_title = [i.text for i in browser.find_elements(By.CLASS_NAME, 'studstaff-subsection-title')]
            stats_count = [i.text for i in browser.find_elements(By.CLASS_NAME, 'studstaff-subsection-count')]
            all_stats = list(zip(stats_title, stats_count))
            student_stats_dict.setdefault(j, all_stats)
        except Exception:
            print('Опять затупил на студентах')
            print(j)
            did_not_work.setdefault(j,i)
            continue

# %% [markdown]
# ### Демонстрация кода

# %% [markdown]
# Так как суммарно все грузится долго - покажу на примере 50 вузов, как работает код и как мы потом собирали датафрейм

# %%
gen_info = [] ### Этот код для того того, чтобы получить ссылки на страницу каждого университета на сайте
url = 'https://www.topuniversities.com/university-rankings/world-university-rankings/2023?qs_qp=topnav'

### И еще важно, чтобы код проработал нормально, окно браузера должно быть полностью открыто. 


with webdriver.Chrome() as browser:
    browser.get(url) ### это главная страница, на которой находятся все ссылки
    browser.maximize_window()
    time.sleep(1)
    
    ### На странице представлено более 1000 университетов. При этом на данный момент в html коде видна инфа только по 10 университетам.
    ### Чтобы это исправить, надо увеличить диапозов видимых университетов до 100. Так будет быстрее
    
    ### В коде ниже мы находим необходимый dropdown, после чего прокручиваем для него страницу. Scrollby как костыль, потому что 
    ### на моем мониторе кнопку после скроллинга перекрывало меню, из-за чего я чутка прокручиваю страницу на вверх
    ### Кстати, к проверяющему: если активируйте код, то, возможно, скроллинга в -100 будет не хватать (или будет слишком много)
    ### Из-за чего кнопка будет не видная и на нее не нажмешь. Нужно будет этот момент проследить.
    change_name = browser.find_elements(By.XPATH, "//div[@class = 'ui fluid  selection dropdown _semantic_select newzindex sort_by_dropdown perpage_dropdown_js inline-block minwidth84 pull-left margin-right-px']")[-1]
    browser.execute_script("return arguments[0].scrollIntoView(true);", change_name)
    browser.execute_script("window.scrollBy(0,-100)")
    change_name.click()
    time.sleep(1)
    
    ### Тут жмем на кнопку и получаем дисплей на 100 университетов
    
    button_100 = browser.find_element(By.XPATH, "//div[@class = 'menu transition visible']/div[4]")
    button_100.click()
    
    time.sleep(10)
    
    ### тут сохраняем кнопочку, на которую нажимаем, когда хотим получить следующие 100 университетов
    button = WebDriverWait(browser, 20).until(EC.element_to_be_clickable((By.XPATH, "//a[@class = 'page-link next']")))
    print(button.location)
    
    ### Сделал while, так как в рейтинге у нас 1420 университетов
    while len(gen_info) < 200:
        
        
        names_links = browser.find_elements(By.CLASS_NAME, 'uni-link') ### Тут узел, создержаштй ссылки
        
        
        names = [i.text for i in names_links] ### Тут имена вузов
        
        rank = [i.text for i in browser.find_elements(By.XPATH, "//div[@class = '_univ-rank hide-this-in-mobile-indi ']")] # позиция
        ### вуза в рейтинге
        
        links = [i.get_attribute('href') for i in names_links] ### Тут уже непосредственно сами ссылки
        
        locations = [i.text for i in browser.find_elements(By.CLASS_NAME, 'location')] ### тут местоположение вуза
        
        ### Здесь итоговые баллые в рейтинге
        points = [i.text for i in browser.find_elements(By.XPATH, "//span[@class = 'overall-score-span hide-this-in-mobile-indi']")] 
        
        first_info = list(zip(rank,names,links,locations,points)) ### тут собираем всю инфу в один tuple
        
        gen_info.extend(first_info) ### и добавляем в общий пул с другими университетами
        
        print(first_info)
        
    
        
        
        ### Тут на всякий пожарный еще рас сохраняю кнопку для нахождения вуза. Когда дойдет до 1420, то кнопка не будет clickable.
        ### Честно, когда комментарии писал - задумался, зачем тут этот трай, но до конца не пойму. Видимо, у меня была какая-то
        ### глубока мысль, из-за которой я решил это использовать
        
        try: 
            button = WebDriverWait(browser, 20).until(EC.element_to_be_clickable((By.XPATH, "//a[@class = 'page-link next']")))
        except Exception:
            print('Спарсили, мэл')
            break

        browser.execute_script("return arguments[0].scrollIntoView(true);", button)
        browser.execute_script("window.scrollBy(0,-200)")
upon Tyne, United Kingdom', '54.8'), ('123', 'Universiti Putra Malaysia (UPM)', 'https://www.topuniversities.com/universities/universiti-putra-malaysia-upm', 'Seri Kembangan, Malaysia', '54.7'), ('124', 'Wageningen University & Research', 'https://www.topuniversities.com/universities/wageningen-university-research', 'Wageningen, Netherlands', '54.6'), ('=125', 'Chalmers University of Technology', 'https://www.topuniversities.com/universities/chalmers-university-technology', 'Gothenburg, Sweden', '54.5'), ('=125', 'Queen Mary University of London', 'https://www.topuniversities.com/universities/queen-mary-university-london', 'London, United Kingdom', '54.5'), ('=125', 'University of Geneva', 'https://www.topuniversities.com/universities/university-geneva', 'Geneva, Switzerland', '54.5'), ('128', 'Uppsala University', 'https://www.topuniversities.com/u ...

# %%
data = pd.DataFrame(gen_info, columns=['rank', 'name', 'link', 'location','points'])

# %%
data.head()
# Out:
#   rank                                         name  \
# 0    1  Massachusetts Institute of Technology (MIT)
# 1    2                      University of Cambridge
# 2    3                          Stanford University
# 3    4                         University of Oxford
# 4    5                           Harvard University
#
#                                                 link  \
# 0  https://www.topuniversities.com/universities/m...
# 1  https://www.topuniversities.com/universities/u...
# 2  https://www.topuniversities.com/universities/s...
# 3  https://www.topuniversities.com/universities/u...
# 4  https://www.topuniversities.com/universities/h...
#
#                     location points
# 0   Cambridge, United States    100
# 1  Cambridge, United Kingdom   98.8
# 2    Stanford, United States   98.5
# 3     Oxford, United Kingdom   98.4
# 4   Cambridge, United States   97.6

# %%
data_50 = data.iloc[:50]

# %%
data_50.shape
# Out:
# (50, 5)

# %%
circle_dict = {} ### Для различных показателей
student_stats_dict = {} ### Для количества студентов

did_not_work = {}

### Тут все более прозаично. Много траев, чтобы из-за одной неспарсенной ячейки код не ломался, а если будет ошибка,
### то будем знать где. Кстати, суммарно парсилось долго.

with webdriver.Chrome(options=chrome_options) as browser:
    browser.get(url)
    browser.maximize_window()
    for i,j in tqdm(list(zip(data['link'].values[:50], data['name'].values[:50]))):
        print(j)
        
        ### Заходим на страничку сайта
        try:
            browser.get(i)
        except Exception:
            print('Страница не загрузилась')
            print(j)
            did_not_work.setdefault(j,i)
            continue
         
        ### Ждеем пока прогрузиться локация (эмпирически выяснил, что если локация прогрузилась, то прогрузилась и вся остальная инфа)
        try:
        
            WebDriverWait(browser, 20).until(EC.presence_of_element_located((By.CLASS_NAME, 'circle')))
            
            ### Тут оценки по 100 шкале за различные показатели
            circles = [tuple(i.text.split('\n')) for i in browser.find_elements(By.CLASS_NAME, 'circle')]
            circle_dict.setdefault(j,circles)
        except Exception:
            print('Затупил на кружочках')
            print(j)
            did_not_work.setdefault(j,i)
            continue
            
        try:   
            ### Тут количество работяг в вузе (то есть преподавателей). Но там опять надо жмыкнуть на кнопку, чтобы найти всю инфу
            stud_staff_but = browser.find_element(By.ID, 'studStaff_Tab')
            browser.execute_script("return arguments[0].scrollIntoView(true);", stud_staff_but)
            browser.execute_script("window.scrollBy(0,-400)")
            stud_staff_but.click()
        except Exception:
            print('Затупил с кнопкой')
            print(j)
            did_not_work.setdefault(j,i)
            continue
        
        try:
            ### Тут уже получаем инфу по количеству студентов.
            WebDriverWait(browser,20).until(EC.visibility_of_all_elements_located((By.CLASS_NAME, 'studstaff-subsection-title')))
            WebDriverWait(browser,20).until(EC.visibility_of_all_elements_located((By.CLASS_NAME, 'studstaff-subsection-count')))
            stats_title = [i.text for i in browser.find_elements(By.CLASS_NAME, 'studstaff-subsection-title')]
            stats_count = [i.text for i in browser.find_elements(By.CLASS_NAME, 'studstaff-subsection-count')]
            all_stats = list(zip(stats_title, stats_count))
            student_stats_dict.setdefault(j, all_stats)
        except Exception:
            print('Опять затупил на студентах')
            print(j)
            did_not_work.setdefault(j,i)
            continue
        
        print(circle_dict)
        print(student_stats_dict)
# Out:
#   0%|                                                                                           | 0/50 [00:00<?, ?it/s]
# Massachusetts Institute of Technology (MIT)
#   2%|█▋                                                                                 | 1/50 [00:18<15:24, 18.86s/it]
# {'Massachusetts Institute of Technology (MIT)': [('100', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('90', 'International Students Ratio'), ('96.1', 'International Research Network'), ('100', 'Employment Outcomes')]}
# {'Massachusetts Institute of Technology (MIT)': [('Total students', '11,035'), ('International students', '3,627'), ('Total faculty staff', '2,919')]}
# University of Cambridge
#   4%|███▎                                                                               | 2/50 [00:24<08:52, 11.10s/it]
# {'Massachusetts Institute of Technology (MIT)': [('100', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('90', 'International Students Ratio'), ('96.1', 'International Research Network'), ('100', 'Employment Outcomes')], 'University of Cambridge': [('98.8', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('92.3', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('96.3', 'International Students Ratio'), ('99.5', 'International Research Network'), ('100', 'Employment Outcomes')]}
# {'Massachusetts Institute of Technology (MIT)': [('Total students', '11,035'), ('International students', '3,627'), ('Total faculty staff', '2,919')], 'University of Cambridge': [('Total students', '20,871'), ('International students', '7,865'), ('Total faculty staff', '5,735')]}
# Stanford University
#   6%|████▉                                                                              | 3/50 [00:35<08:34, 10.94s/it]
# {'Massachusetts Institute of Technology (MIT)': [('100', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('90', 'International Students Ratio'), ('96.1', 'International Research Network'), ('100', 'Employment Outcomes')], 'University of Cambridge': [('98.8', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('92.3', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('96.3', 'International Students Ratio'), ('99.5', 'International Research Network'), ('100', 'Employment Outcomes')], 'Stanford University': [('98.5', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('99.9', 'Citations per Faculty'), ('99.8', 'International Faculty Ratio'), ('60.3', 'International Students Ratio'), ('96.3', 'International Research Network'), ('100', 'Employment Outcomes')]}
# {'Massachusetts Institute of Technology (MIT)': [('Total students', '11,035'), ('International students', '3,627'), ('Total faculty staff', '2,919')], 'University of Cambridge': [('Total students', '20,871'), ('International students', '7,865'), ('Total faculty staff', '5,735')], 'Stanford University': [('Total students', '14,518'), ('International students', '3,318'), ('Total faculty staff', '4,694')]}
# University of Oxford
#   8%|██████▋                                                                            | 4/50 [00:46<08:28, 11.06s/it]
# {'Massachusetts Institute of Technology (MIT)': [('100', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('90', 'International Students Ratio'), ('96.1', 'International Research Network'), ('100', 'Employment Outcomes')], 'University of Cambridge': [('98.8', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('92.3', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('96.3', 'International Students Ratio'), ('99.5', 'International Research Network'), ('100', 'Employment Outcomes')], 'Stanford University': [('98.5', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('99.9', 'Citations per Faculty'), ('99.8', 'International Faculty Ratio'), ('60.3', 'International Students Ratio'), ('96.3', 'International Research Network'), ('100', 'Employment Outcomes')], 'University of Oxford': [('98.4', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('90', 'Citations per Faculty'), ('98.8', 'International Faculty Ratio'), ('98.4', 'International Students Ratio'), ('99.9', 'International Research Network'), ('100', 'Employment Outcomes')]}
# {'Massachusetts Institute of Technology (MIT)': [('Total students', '11,035'), ('International students', '3,627'), ('Total faculty staff', '2,919')], 'University of Cambridge': [('Total students', '20,871'), ('International students', '7,865'), ('Total faculty staff', '5,735')], 'Stanford University': [('Total students', '14,518'), ('International students', '3,318'), ('Total faculty staff', '4,694')], 'University of Oxford': [('Total students', '21,972'), ('International students', '9,024'), ('Total faculty staff', '6,650')]}
# Harvard University
#  10%|████████▎                                                                          | 5/50 [00:52<06:56,  9.25s/it]
# {'Massachusetts Institute of Technology (MIT)': [('100', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('90', 'International Students Ratio'), ('96.1', 'International Research Network'), ('100', 'Employment Outcomes')], 'University of Cambridge': [('98.8', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('92.3', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('96.3', 'International Students Ratio'), ('99.5', 'International Research Network'), ('100', 'Employment Outcomes')], 'Stanford University': [('98.5', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('99.9', 'Citations per Faculty'), ('99.8', 'International Faculty Ratio'), ('60.3', 'International Students Ratio'), ('96.3', 'International Research Network'), ('100', 'Employment Outcomes')], 'University of Oxford': [('98.4', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('90', 'Citations per Faculty'), ('98.8', 'International Faculty Ratio'), ('98.4', 'International Students Ratio'), ('99.9', 'International Research Network'), ('100', 'Employment Outcomes')], 'Harvard University': [('97.6', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('99.4', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('76.9', 'International Faculty Ratio'), ('66.9', 'International Students Ratio'), ('100', 'International Research Network'), ('100', 'Employment Outcomes')]}
# {'Massachusetts Institute of Technology (MIT)': [('Total students', '11,035'), ('International students', '3,627'), ('Total faculty staff', '2,919')], 'University of Cambridge': [('Total students', '20,871'), ('International students', '7,865'), ('Total faculty staff', '5,735')], 'Stanford University': [('Total students', '14,518'), ('International students', '3,318'), ('Total faculty staff', '4,694')], 'University of Oxford': [('Total students', '21,972'), ('International students', '9,024'), ('Total faculty staff', '6,650')], 'Harvard University': [('Total students', '21,877'), ('International students', '5,379'), ('Total faculty staff', '4,480')]}
# California Institute of Technology (Caltech)
#  12%|█████████▉                                                                         | 6/50 [01:01<06:40,  9.11s/it]
# {'Massachusetts Institute of Technology (MIT)': [('100', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('90', 'International Students Ratio'), ('96.1', 'International Research Network'), ('100', 'Employment Outcomes')], 'University of Cambridge': [('98.8', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('92.3', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('96.3', 'International Students Ratio'), ('99.5', 'International Research Network'), ('100', 'Employment Outcomes')], 'Stanford University': [('98.5', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('99.9', 'Citations per Faculty'), ('99.8', 'International Faculty Ratio'), ('60.3', 'International Students Ratio'), ('96.3', 'International Research Network'), ('100', 'Employment Outcomes')], 'University of Oxford': [('98.4', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('90', 'Citations per Faculty'), ('98.8', 'International Faculty Ratio'), ('98.4', 'International Students Ratio'), ('99.9', 'International Research Network'), ('100', 'Employment Outcomes')], 'Harvard University': [('97.6', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('99.4', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('76.9', 'International Faculty Ratio'), ('66.9', 'International Students Ratio'), ('100', 'International Research Network'), ('100', 'Employment Outcomes')], 'California Institute of Technology (Caltech)': [('97', 'Overall'), ('96.5', 'Academic Reputation'), ('87.1', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('99.8', 'International Faculty Ratio'), ('85.1', 'International Students Ratio'), ('73', 'International Research Network'), ('98.8', 'Employment Outcomes')]}
# {'Massachusetts Institute of Technology (MIT)': [('Total students', '11,035'), ('International students', '3,627'), ('Total faculty staff', '2,919')], 'University of Cambridge': [('Total students', '20,871'), ('International students', '7,865'), ('Total faculty staff', '5,735')], 'Stanford University': [('Total students', '14,518'), ('International students', '3,318'), ('Total faculty staff', '4,694')], 'University of Oxford': [('Total students', '21,972'), ('International students', '9,024'), ('Total faculty staff', '6,650')], 'Harvard University': [('Total students', '21,877'), ('International students', '5,379'), ('Total faculty staff', '4,480')], 'California Institute of Technology (Caltech)': [('Total students', '2,240'), ('International students', '683'), ('Total faculty staff', '969')]}
# Imperial College London
#  14%|███████████▌                                                                       | 7/50 [01:20<08:45, 12.23s/it]
# {'Massachusetts Institute of Technology (MIT)': [('100', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('90', 'International Students Ratio'), ('96.1', 'International Research Network'), ('100', 'Employment Outcomes')], 'University of Cambridge': [('98.8', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('92.3', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('96.3', 'International Students Ratio'), ('99.5', 'International Research Network'), ('100', 'Employment Outcomes')], 'Stanford University': [('98.5', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('99.9', 'Citations per Faculty'), ('99.8', 'International Faculty Ratio'), ('60.3', 'International Students Ratio'), ('96.3', 'International Research Network'), ('100', 'Employment Outcomes')], 'University of Oxford': [('98.4', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('90', 'Citations per Faculty'), ('98.8', 'International Faculty Ratio'), ('98.4', 'International Students Ratio'), ('99.9', 'International Research Network'), ('100', 'Employment Outcomes')], 'Harvard University': [('97.6', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('99.4', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('76.9', 'International Faculty Ratio'), ('66.9', 'International Students Ratio'), ('100', 'International Research Network'), ('100', 'Employment Outcomes')], 'California Institute of Technology (Caltech)': [('97', 'Overall'), ('96.5', 'Academic Reputation'), ('87.1', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('99.8', 'International Faculty Ratio'), ('85.1', 'International Students Ratio'), ('73', 'International Research Network'), ('98.8', 'Employment Outcomes')], 'Imperial College London': [('97', 'Overall'), ('98.3', 'Academic Reputation'), ('99.7', 'Employer Reputation'), ('99.5', 'Faculty Student Ratio'), ('86.5', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('100', 'International Students Ratio'), ('98.1', 'International Research Network'), ('88.8', 'Employment Outcomes')]}
# {'Massachusetts Institute of Technology (MIT)': [('Total students', '11,035'), ('International students', '3,627'), ('Total faculty staff', '2,919')], 'University of Cambridge': [('Total students', '20,871'), ('International students', '7,865'), ('Total faculty staff', '5,735')], 'Stanford University': [('Total students', '14,518'), ('International students', '3,318'), ('Total faculty staff', '4,694')], 'University of Oxford': [('Total students', '21,972'), ('International students', '9,024'), ('Total faculty staff', '6,650')], 'Harvard University': [('Total students', '21,877'), ('International students', '5,379'), ('Total faculty staff', '4,480')], 'California Institute of Technology (Caltech)': [('Total students', '2,240'), ('International students', '683'), ('Total faculty staff', '969')], 'Imperial College London': [('Total students', '20,191'), ('International students', '12,332'), ('Total faculty staff', '4,099')]}
# UCL
#  16%|█████████████▎                                                                     | 8/50 [01:35<09:13, 13.19s/it]
# {'Massachusetts Institute of Technology (MIT)': [('100', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('90', 'International Students Ratio'), ('96.1', 'International Research Network'), ('100', 'Employment Outcomes')], 'University of Cambridge': [('98.8', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('92.3', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('96.3', 'International Students Ratio'), ('99.5', 'International Research Network'), ('100', 'Employment Outcomes')], 'Stanford University': [('98.5', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('99.9', 'Citations per Faculty'), ('99.8', 'International Faculty Ratio'), ('60.3', 'International Students Ratio'), ('96.3', 'International Research Network'), ('100', 'Employment Outcomes')], 'University of Oxford': [('98.4', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('90', 'Citations per Faculty'), ('98.8', 'International Faculty Ratio'), ('98.4', 'International Students Ratio'), ('99.9', 'International Research Network'), ('100', 'Employment Outcomes')], 'Harvard University': [('97.6', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('99.4', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('76.9', 'International Faculty Ratio'), ('66.9', 'International Students Ratio'), ('100', 'International Research Network'), ('100', 'Employment Outcomes')], 'California Institute of Technology (Caltech)': [('97', 'Overall'), ('96.5', 'Academic Reputation'), ('87.1', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('99.8', 'International Faculty Ratio'), ('85.1', 'International Students Ratio'), ('73', 'International Research Network'), ('98.8', 'Employment Outcomes')], 'Imperial College London': [('97', 'Overall'), ('98.3', 'Academic Reputation'), ('99.7', 'Employer Reputation'), ('99.5', 'Faculty Student Ratio'), ('86.5', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('100', 'International Students Ratio'), ('98.1', 'International Research Network'), ('88.8', 'Employment Outcomes')], 'UCL': [('95', 'Overall'), ('99.4', 'Academic Reputation'), ('98.6', 'Employer Reputation'), ('97.6', 'Faculty Student Ratio'), ('77', 'Citations per Faculty'), ('99.2', 'International Faculty Ratio'), ('100', 'International Students Ratio'), ('100', 'International Research Network'), ('90.3', 'Employment Outcomes')]}
# {'Massachusetts Institute of Technology (MIT)': [('Total students', '11,035'), ('International students', '3,627'), ('Total faculty staff', '2,919')], 'University of Cambridge': [('Total students', '20,871'), ('International students', '7,865'), ('Total faculty staff', '5,735')], 'Stanford University': [('Total students', '14,518'), ('International students', '3,318'), ('Total faculty staff', '4,694')], 'University of Oxford': [('Total students', '21,972'), ('International students', '9,024'), ('Total faculty staff', '6,650')], 'Harvard University': [('Total students', '21,877'), ('International students', '5,379'), ('Total faculty staff', '4,480')], 'California Institute of Technology (Caltech)': [('Total students', '2,240'), ('International students', '683'), ('Total faculty staff', '969')], 'Imperial College London': [('Total students', '20,191'), ('International students', '12,332'), ('Total faculty staff', '4,099')], 'UCL': [('Total students', '41,194'), ('International students', '25,076'), ('Total faculty staff', '7,251')]}
# ETH Zurich
#  18%|██████████████▉                                                                    | 9/50 [01:45<08:17, 12.14s/it]
# {'Massachusetts Institute of Technology (MIT)': [('100', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('90', 'International Students Ratio'), ('96.1', 'International Research Network'), ('100', 'Employment Outcomes')], 'University of Cambridge': [('98.8', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('92.3', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('96.3', 'International Students Ratio'), ('99.5', 'International Research Network'), ('100', 'Employment Outcomes')], 'Stanford University': [('98.5', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('99.9', 'Citations per Faculty'), ('99.8', 'International Faculty Ratio'), ('60.3', 'International Students Ratio'), ('96.3', 'International Research Network'), ('100', 'Employment Outcomes')], 'University of Oxford': [('98.4', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('90', 'Citations per Faculty'), ('98.8', 'International Faculty Ratio'), ('98.4', 'International Students Ratio'), ('99.9', 'International Research Network'), ('100', 'Employment Outcomes')], 'Harvard University': [('97.6', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('99.4', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('76.9', 'International Faculty Ratio'), ('66.9', 'International Students Ratio'), ('100', 'International Research Network'), ('100', 'Employment Outcomes')], 'California Institute of Technology (Caltech)': [('97', 'Overall'), ('96.5', 'Academic Reputation'), ('87.1', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('99.8', 'International Faculty Ratio'), ('85.1', 'International Students Ratio'), ('73', 'International Research Network'), ('98.8', 'Employment Outcomes')], 'Imperial College London': [('97', 'Overall'), ('98.3', 'Academic Reputation'), ('99.7', 'Employer Reputation'), ('99.5', 'Faculty Student Ratio'), ('86.5', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('100', 'International Students Ratio'), ('98.1', 'International Research Network'), ('88.8', 'Employment Outcomes')], 'UCL': [('95', 'Overall'), ('99.4', 'Academic Reputation'), ('98.6', 'Employer Reputation'), ('97.6', 'Faculty Student Ratio'), ('77', 'Citations per Faculty'), ('99.2', 'International Faculty Ratio'), ('100', 'International Students Ratio'), ('100', 'International Research Network'), ('90.3', 'Employment Outcomes')], 'ETH Zurich': [('93.6', 'Overall'), ('98.6', 'Academic Reputation'), ('91.3', 'Employer Reputation'), ('74.2', 'Faculty Student Ratio'), ('99.2', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('98', 'International Students Ratio'), ('96.2', 'International Research Network'), ('91.1', 'Employment Outcomes')]}
# {'Massachusetts Institute of Technology (MIT)': [('Total students', '11,035'), ('International students', '3,627'), ('Total faculty staff', '2,919')], 'University of Cambridge': [('Total students', '20,871'), ('International students', '7,865'), ('Total faculty staff', '5,735')], 'Stanford University': [('Total students', '14,518'), ('International students', '3,318'), ('Total faculty staff', '4,694')], 'University of Oxford': [('Total students', '21,972'), ('International students', '9,024'), ('Total faculty staff', '6,650')], 'Harvard University': [('Total students', '21,877'), ('International students', '5,379'), ('Total faculty staff', '4,480')], 'California Institute of Technology (Caltech)': [('Total students', '2,240'), ('International students', '683'), ('Total faculty staff', '969')], 'Imperial College London': [('Total students', '20,191'), ('International students', '12,332'), ('Total faculty staff', '4,099')], 'UCL': [('Total students', '41,194'), ('International students', '25,076'), ('Total faculty staff', '7,251')], 'ETH Zurich': [('Total students', '20,892'), ('International students', '8,420'), ('Total faculty staff', '2,820')]}
# University of Chicago
#  20%|████████████████▍                                                                 | 10/50 [01:55<07:44, 11.60s/it]
# {'Massachusetts Institute of Technology (MIT)': [('100', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('90', 'International Students Ratio'), ('96.1', 'International Research Network'), ('100', 'Employment Outcomes')], 'University of Cambridge': [('98.8', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('92.3', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('96.3', 'International Students Ratio'), ('99.5', 'International Research Network'), ('100', 'Employment Outcomes')], 'Stanford University': [('98.5', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('99.9', 'Citations per Faculty'), ('99.8', 'International Faculty Ratio'), ('60.3', 'International Students Ratio'), ('96.3', 'International Research Network'), ('100', 'Employment Outcomes')], 'University of Oxford': [('98.4', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('90', 'Citations per Faculty'), ('98.8', 'International Faculty Ratio'), ('98.4', 'International Students Ratio'), ('99.9', 'International Research Network'), ('100', 'Employment Outcomes')], 'Harvard University': [('97.6', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('99.4', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('76.9', 'International Faculty Ratio'), ('66.9', 'International Students Ratio'), ('100', 'International Research Network'), ('100', 'Employment Outcomes')], 'California Institute of Technology (Caltech)': [('97', 'Overall'), ('96.5', 'Academic Reputation'), ('87.1', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('99.8', 'International Faculty Ratio'), ('85.1', 'International Students Ratio'), ('73', 'International Research Network'), ('98.8', 'Employment Outcomes')], 'Imperial College London': [('97', 'Overall'), ('98.3', 'Academic Reputation'), ('99.7', 'Employer Reputation'), ('99.5', 'Faculty Student Ratio'), ('86.5', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('100', 'International Students Ratio'), ('98.1', 'International Research Network'), ('88.8', 'Employment Outcomes')], 'UCL': [('95', 'Overall'), ('99.4', 'Academic Reputation'), ('98.6', 'Employer Reputation'), ('97.6', 'Faculty Student Ratio'), ('77', 'Citations per Faculty'), ('99.2', 'International Faculty Ratio'), ('100', 'International Students Ratio'), ('100', 'International Research Network'), ('90.3', 'Employment Outcomes')], 'ETH Zurich': [('93.6', 'Overall'), ('98.6', 'Academic Reputation'), ('91.3', 'Employer Reputation'), ('74.2', 'Faculty Student Ratio'), ('99.2', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('98', 'International Students Ratio'), ('96.2', 'International Research Network'), ('91.1', 'Employment Outcomes')], 'University of Chicago': [('93.2', 'Overall'), ('99.2', 'Academic Reputation'), ('92.2', 'Employer Reputation'), ('92.9', 'Faculty Student Ratio'), ('86.8', 'Citations per Faculty'), ('81.6', 'International Faculty Ratio'), ('76', 'International Students Ratio'), ('89.6', 'International Research Network'), ('98.2', 'Employment Outcomes')]}
# {'Massachusetts Institute of Technology (MIT)': [('Total students', '11,035'), ('International students', '3,627'), ('Total faculty staff', '2,919')], 'University of Cambridge': [('Total students', '20,871'), ('International students', '7,865'), ('Total faculty staff', '5,735')], 'Stanford University': [('Total students', '14,518'), ('International students', '3,318'), ('Total faculty staff', '4,694')], 'University of Oxford': [('Total students', '21,972'), ('International students', '9,024'), ('Total faculty staff', '6,650')], 'Harvard University': [('Total students', '21,877'), ('International students', '5,379'), ('Total faculty staff', '4,480')], 'California Institute of Technology (Caltech)': [('Total students', '2,240'), ('International students', '683'), ('Total faculty staff', '969')], 'Imperial College London': [('Total students', '20,191'), ('International students', '12,332'), ('Total faculty staff', '4,099')], 'UCL': [('Total students', '41,194'), ('International students', '25,076'), ('Total faculty staff', '7,251')], 'ETH Zurich': [('Total students', '20,892'), ('International students', '8,420'), ('Total faculty staff', '2,820')], 'University of Chicago': [('Total students', '16,325'), ('International students', '4,442'), ('Total faculty staff', '2,703')]}
# National University of Singapore (NUS)
#  22%|██████████████████                                                                | 11/50 [02:08<07:49, 12.04s/it]
# {'Massachusetts Institute of Technology (MIT)': [('100', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('90', 'International Students Ratio'), ('96.1', 'International Research Network'), ('100', 'Employment Outcomes')], 'University of Cambridge': [('98.8', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('92.3', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('96.3', 'International Students Ratio'), ('99.5', 'International Research Network'), ('100', 'Employment Outcomes')], 'Stanford University': [('98.5', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('99.9', 'Citations per Faculty'), ('99.8', 'International Faculty Ratio'), ('60.3', 'International Students Ratio'), ('96.3', 'International Research Network'), ('100', 'Employment Outcomes')], 'University of Oxford': [('98.4', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('90', 'Citations per Faculty'), ('98.8', 'International Faculty Ratio'), ('98.4', 'International Students Ratio'), ('99.9', 'International Research Network'), ('100', 'Employment Outcomes')], 'Harvard University': [('97.6', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('99.4', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('76.9', 'International Faculty Ratio'), ('66.9', 'International Students Ratio'), ('100', 'International Research Network'), ('100', 'Employment Outcomes')], 'California Institute of Technology (Caltech)': [('97', 'Overall'), ('96.5', 'Academic Reputation'), ('87.1', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('99.8', 'International Faculty Ratio'), ('85.1', 'International Students Ratio'), ('73', 'International Research Network'), ('98.8', 'Employment Outcomes')], 'Imperial College London': [('97', 'Overall'), ('98.3', 'Academic Reputation'), ('99.7', 'Employer Reputation'), ('99.5', 'Faculty Student Ratio'), ('86.5', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('100', 'International Students Ratio'), ('98.1', 'International Research Network'), ('88.8', 'Employment Outcomes')], 'UCL': [('95', 'Overall'), ('99.4', 'Academic Reputation'), ('98.6', 'Employer Reputation'), ('97.6', 'Faculty Student Ratio'), ('77', 'Citations per Faculty'), ('99.2', 'International Faculty Ratio'), ('100', 'International Students Ratio'), ('100', 'International Research Network'), ('90.3', 'Employment Outcomes')], 'ETH Zurich': [('93.6', 'Overall'), ('98.6', 'Academic Reputation'), ('91.3', 'Employer Reputation'), ('74.2', 'Faculty Student Ratio'), ('99.2', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('98', 'International Students Ratio'), ('96.2', 'International Research Network'), ('91.1', 'Employment Outcomes')], 'University of Chicago': [('93.2', 'Overall'), ('99.2', 'Academic Reputation'), ('92.2', 'Employer Reputation'), ('92.9', 'Faculty Student Ratio'), ('86.8', 'Citations per Faculty'), ('81.6', 'International Faculty Ratio'), ('76', 'International Students Ratio'), ('89.6', 'International Research Network'), ('98.2', 'Employment Outcomes')], 'National University of Singapore (NUS)': [('92.7', 'Overall'), ('99.5', 'Academic Reputation'), ('94.1', 'Employer Reputation'), ('79.8', 'Faculty Student Ratio'), ('91.8', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('73.5', 'International Students Ratio'), ('89.9', 'International Research Network'), ('99.6', 'Employment Outcomes')]}
# {'Massachusetts Institute of Technology (MIT)': [('Total students', '11,035'), ('International students', '3,627'), ('Total faculty staff', '2,919')], 'University of Cambridge': [('Total students', '20,871'), ('International students', '7,865'), ('Total faculty staff', '5,735')], 'Stanford University': [('Total students', '14,518'), ('International students', '3,318'), ('Total faculty staff', '4,694')], 'University of Oxford': [('Total students', '21,972'), ('International students', '9,024'), ('Total faculty staff', '6,650')], 'Harvard University': [('Total students', '21,877'), ('International students', '5,379'), ('Total faculty staff', '4,480')], 'California Institute of Technology (Caltech)': [('Total students', '2,240'), ('International students', '683'), ('Total faculty staff', '969')], 'Imperial College London': [('Total students', '20,191'), ('International students', '12,332'), ('Total faculty staff', '4,099')], 'UCL': [('Total students', '41,194'), ('International students', '25,076'), ('Total faculty staff', '7,251')], 'ETH Zurich': [('Total students', '20,892'), ('International students', '8,420'), ('Total faculty staff', '2,820')], 'University of Chicago': [('Total students', '16,325'), ('International students', '4,442'), ('Total faculty staff', '2,703')], 'National University of Singapore (NUS)': [('Total students', '30,725'), ('International students', '8,129'), ('Total faculty staff', '4,268')]}
# Peking University
#  24%|███████████████████▋                                                              | 12/50 [02:17<06:56, 10.95s/it]
# {'Massachusetts Institute of Technology (MIT)': [('100', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('90', 'International Students Ratio'), ('96.1', 'International Research Network'), ('100', 'Employment Outcomes')], 'University of Cambridge': [('98.8', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('92.3', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('96.3', 'International Students Ratio'), ('99.5', 'International Research Network'), ('100', 'Employment Outcomes')], 'Stanford University': [('98.5', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('99.9', 'Citations per Faculty'), ('99.8', 'International Faculty Ratio'), ('60.3', 'International Students Ratio'), ('96.3', 'International Research Network'), ('100', 'Employment Outcomes')], 'University of Oxford': [('98.4', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('90', 'Citations per Faculty'), ('98.8', 'International Faculty Ratio'), ('98.4', 'International Students Ratio'), ('99.9', 'International Research Network'), ('100', 'Employment Outcomes')], 'Harvard University': [('97.6', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('99.4', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('76.9', 'International Faculty Ratio'), ('66.9', 'International Students Ratio'), ('100', 'International Research Network'), ('100', 'Employment Outcomes')], 'California Institute of Technology (Caltech)': [('97', 'Overall'), ('96.5', 'Academic Reputation'), ('87.1', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('99.8', 'International Faculty Ratio'), ('85.1', 'International Students Ratio'), ('73', 'International Research Network'), ('98.8', 'Employment Outcomes')], 'Imperial College London': [('97', 'Overall'), ('98.3', 'Academic Reputation'), ('99.7', 'Employer Reputation'), ('99.5', 'Faculty Student Ratio'), ('86.5', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('100', 'International Students Ratio'), ('98.1', 'International Research Network'), ('88.8', 'Employment Outcomes')], 'UCL': [('95', 'Overall'), ('99.4', 'Academic Reputation'), ('98.6', 'Employer Reputation'), ('97.6', 'Faculty Student Ratio'), ('77', 'Citations per Faculty'), ('99.2', 'International Faculty Ratio'), ('100', 'International Students Ratio'), ('100', 'International Research Network'), ('90.3', 'Employment Outcomes')], 'ETH Zurich': [('93.6', 'Overall'), ('98.6', 'Academic Reputation'), ('91.3', 'Employer Reputation'), ('74.2', 'Faculty Student Ratio'), ('99.2', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('98', 'International Students Ratio'), ('96.2', 'International Research Network'), ('91.1', 'Employment Outcomes')], 'University of Chicago': [('93.2', 'Overall'), ('99.2', 'Academic Reputation'), ('92.2', 'Employer Reputation'), ('92.9', 'Faculty Student Ratio'), ('86.8', 'Citations per Faculty'), ('81.6', 'International Faculty Ratio'), ('76', 'International Students Ratio'), ('89.6', 'International Research Network'), ('98.2', 'Employment Outcomes')], 'National University of Singapore (NUS)': [('92.7', 'Overall'), ('99.5', 'Academic Reputation'), ('94.1', 'Employer Reputation'), ('79.8', 'Faculty Student Ratio'), ('91.8', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('73.5', 'International Students Ratio'), ('89.9', 'International Research Network'), ('99.6', 'Employment Outcomes')], 'Peking University': [('91.3', 'Overall'), ('99.3', 'Academic Reputation'), ('96.5', 'Employer Reputation'), ('87.3', 'Faculty Student Ratio'), ('96.7', 'Citations per Faculty'), ('57.1', 'International Faculty Ratio'), ('36.9', 'Inter ...
# {'Massachusetts Institute of Technology (MIT)': [('Total students', '11,035'), ('International students', '3,627'), ('Total faculty staff', '2,919')], 'University of Cambridge': [('Total students', '20,871'), ('International students', '7,865'), ('Total faculty staff', '5,735')], 'Stanford University': [('Total students', '14,518'), ('International students', '3,318'), ('Total faculty staff', '4,694')], 'University of Oxford': [('Total students', '21,972'), ('International students', '9,024'), ('Total faculty staff', '6,650')], 'Harvard University': [('Total students', '21,877'), ('International students', '5,379'), ('Total faculty staff', '4,480')], 'California Institute of Technology (Caltech)': [('Total students', '2,240'), ('International students', '683'), ('Total faculty staff', '969')], 'Imperial College London': [('Total students', '20,191'), ('International students', '12,332'), ('Total faculty staff', '4,099')], 'UCL': [('Total students', '41,194'), ('International students', '25,076'), ('Total faculty staff', '7,251')], 'ETH Zurich': [('Total students', '20,892'), ('International students', '8,420'), ('Total faculty staff', '2,820')], 'University of Chicago': [('Total students', '16,325'), ('International students', '4,442'), ('Total faculty staff', '2,703')], 'National University of Singapore (NUS)': [('Total students', '30,725'), ('International students', '8,129'), ('Total faculty staff', '4,268')], 'Peking University': [('Total students', '31,873'), ('International students', '5,436'), ('Total faculty staff', '5,361')]}
# University of Pennsylvania
#  26%|█████████████████████▎                                                            | 13/50 [02:26<06:25, 10.43s/it]
# {'Massachusetts Institute of Technology (MIT)': [('100', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('90', 'International Students Ratio'), ('96.1', 'International Research Network'), ('100', 'Employment Outcomes')], 'University of Cambridge': [('98.8', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('92.3', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('96.3', 'International Students Ratio'), ('99.5', 'International Research Network'), ('100', 'Employment Outcomes')], 'Stanford University': [('98.5', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('99.9', 'Citations per Faculty'), ('99.8', 'International Faculty Ratio'), ('60.3', 'International Students Ratio'), ('96.3', 'International Research Network'), ('100', 'Employment Outcomes')], 'University of Oxford': [('98.4', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('90', 'Citations per Faculty'), ('98.8', 'International Faculty Ratio'), ('98.4', 'International Students Ratio'), ('99.9', 'International Research Network'), ('100', 'Employment Outcomes')], 'Harvard University': [('97.6', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('99.4', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('76.9', 'International Faculty Ratio'), ('66.9', 'International Students Ratio'), ('100', 'International Research Network'), ('100', 'Employment Outcomes')], 'California Institute of Technology (Caltech)': [('97', 'Overall'), ('96.5', 'Academic Reputation'), ('87.1', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('99.8', 'International Faculty Ratio'), ('85.1', 'International Students Ratio'), ('73', 'International Research Network'), ('98.8', 'Employment Outcomes')], 'Imperial College London': [('97', 'Overall'), ('98.3', 'Academic Reputation'), ('99.7', 'Employer Reputation'), ('99.5', 'Faculty Student Ratio'), ('86.5', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('100', 'International Students Ratio'), ('98.1', 'International Research Network'), ('88.8', 'Employment Outcomes')], 'UCL': [('95', 'Overall'), ('99.4', 'Academic Reputation'), ('98.6', 'Employer Reputation'), ('97.6', 'Faculty Student Ratio'), ('77', 'Citations per Faculty'), ('99.2', 'International Faculty Ratio'), ('100', 'International Students Ratio'), ('100', 'International Research Network'), ('90.3', 'Employment Outcomes')], 'ETH Zurich': [('93.6', 'Overall'), ('98.6', 'Academic Reputation'), ('91.3', 'Employer Reputation'), ('74.2', 'Faculty Student Ratio'), ('99.2', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('98', 'International Students Ratio'), ('96.2', 'International Research Network'), ('91.1', 'Employment Outcomes')], 'University of Chicago': [('93.2', 'Overall'), ('99.2', 'Academic Reputation'), ('92.2', 'Employer Reputation'), ('92.9', 'Faculty Student Ratio'), ('86.8', 'Citations per Faculty'), ('81.6', 'International Faculty Ratio'), ('76', 'International Students Ratio'), ('89.6', 'International Research Network'), ('98.2', 'Employment Outcomes')], 'National University of Singapore (NUS)': [('92.7', 'Overall'), ('99.5', 'Academic Reputation'), ('94.1', 'Employer Reputation'), ('79.8', 'Faculty Student Ratio'), ('91.8', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('73.5', 'International Students Ratio'), ('89.9', 'International Research Network'), ('99.6', 'Employment Outcomes')], 'Peking University': [('91.3', 'Overall'), ('99.3', 'Academic Reputation'), ('96.5', 'Employer Reputation'), ('87.3', 'Faculty Student Ratio'), ('96.7', 'Citations per Faculty'), ('57.1', 'International Faculty Ratio'), ('36.9', 'Inter ...
# {'Massachusetts Institute of Technology (MIT)': [('Total students', '11,035'), ('International students', '3,627'), ('Total faculty staff', '2,919')], 'University of Cambridge': [('Total students', '20,871'), ('International students', '7,865'), ('Total faculty staff', '5,735')], 'Stanford University': [('Total students', '14,518'), ('International students', '3,318'), ('Total faculty staff', '4,694')], 'University of Oxford': [('Total students', '21,972'), ('International students', '9,024'), ('Total faculty staff', '6,650')], 'Harvard University': [('Total students', '21,877'), ('International students', '5,379'), ('Total faculty staff', '4,480')], 'California Institute of Technology (Caltech)': [('Total students', '2,240'), ('International students', '683'), ('Total faculty staff', '969')], 'Imperial College London': [('Total students', '20,191'), ('International students', '12,332'), ('Total faculty staff', '4,099')], 'UCL': [('Total students', '41,194'), ('International students', '25,076'), ('Total faculty staff', '7,251')], 'ETH Zurich': [('Total students', '20,892'), ('International students', '8,420'), ('Total faculty staff', '2,820')], 'University of Chicago': [('Total students', '16,325'), ('International students', '4,442'), ('Total faculty staff', '2,703')], 'National University of Singapore (NUS)': [('Total students', '30,725'), ('International students', '8,129'), ('Total faculty staff', '4,268')], 'Peking University': [('Total students', '31,873'), ('International students', '5,436'), ('Total faculty staff', '5,361')], 'University of Pennsylvania': [('Total students', '22,261'), ('International students', '5,426'), ('Total faculty staff', '5,069')]}
# Tsinghua University
#  28%|██████████████████████▉                                                           | 14/50 [02:39<06:45, 11.26s/it]
# ...
# {'Massachusetts Institute of Technology (MIT)': [('Total students', '11,035'), ('International students', '3,627'), ('Total faculty staff', '2,919')], 'University of Cambridge': [('Total students', '20,871'), ('International students', '7,865'), ('Total faculty staff', '5,735')], 'Stanford University': [('Total students', '14,518'), ('International students', '3,318'), ('Total faculty staff', '4,694')], 'University of Oxford': [('Total students', '21,972'), ('International students', '9,024'), ('Total faculty staff', '6,650')], 'Harvard University': [('Total students', '21,877'), ('International students', '5,379'), ('Total faculty staff', '4,480')], 'California Institute of Technology (Caltech)': [('Total students', '2,240'), ('International students', '683'), ('Total faculty staff', '969')], 'Imperial College London': [('Total students', '20,191'), ('International students', '12,332'), ('Total faculty staff', '4,099')], 'UCL': [('Total students', '41,194'), ('International students', '25,076'), ('Total faculty staff', '7,251')], 'ETH Zurich': [('Total students', '20,892'), ('International students', '8,420'), ('Total faculty staff', '2,820')], 'University of Chicago': [('Total students', '16,325'), ('International students', '4,442'), ('Total faculty staff', '2,703')], 'National University of Singapore (NUS)': [('Total students', '30,725'), ('International students', '8,129'), ('Total faculty staff', '4,268')], 'Peking University': [('Total students', '31,873'), ('International students', '5,436'), ('Total faculty staff', '5,361')], 'University of Pennsylvania': [('Total students', '22,261'), ('International students', '5,426'), ('Total faculty staff', '5,069')], 'Tsinghua University': [('Total students', '36,893'), ('International students', '5,162'), ('Total faculty staff', '6,136')], 'The University of Edinburgh': [('Total students', '33,861'), ('International students', '15,268'), ('Total faculty staff', '4,865')], 'EPFL': [('Total students', '10,919'), ('International students', '6,837'), ('Total faculty staff', '1,757')], 'Princeton University': [('Total students', '7,767'), ('International students', '1,813'), ('Total faculty staff', '1,066')], 'Yale University': [('Total students', '11,283'), ('International students', '3,118'), ('Total faculty staff', '5,527')], 'Nanyang Technological University, Singapore (NTU Singapore)': [('Total students', '25,895'), ('International students', '6,900'), ('Total faculty staff', '3,735')], 'Cornell University': [('Total students', '23,188'), ('International students', '5,015'), ('Total faculty staff', '2,838')], 'The University of Hong Kong': [('Total students', '19,958'), ('International students', '8,353'), ('Total faculty staff', '2,957')], 'Columbia University': [('Total students', '25,914'), ('International students', '8,686'), ('Total faculty staff', '7,401')], 'The University of Tokyo': [('Total students', '27,826'), ('International students', '4,063'), ('Total faculty staff', '4,534')], 'Johns Hopkins University': [('Total students', '14,891'), ('International students', '4,251'), ('Total faculty staff', '4,969')], 'University of Michigan-Ann Arbor': [('Total students', '45,651'), ('International students', '7,341'), ('Total faculty staff', '7,132')], 'Université PSL': [('Total students', '14,591'), ('International students', '5,536'), ('Total faculty staff', '3,180')], 'University of California, Berkeley (UCB)': [('Total students', '40,468'), ('International students', '8,989'), ('Total faculty staff', '3,405')], 'The University of Manchester': [('Total students', '41,182'), ('International students', '18,345'), ('Total faculty staff', '4,829')], 'Seoul National University': [('Total students', '24,451'), ('International students', '2,014'), ('Total faculty staff', '3,838')], 'Australian National University (ANU)': [('Total students', '17,269'), ('International students', '6,152'), ('Total faculty staff', '1,716')], 'McGill University': [('Total students', '30,391'), ('In ...
# Duke University
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [11:29<00:00, 13.79s/it]
# {'Massachusetts Institute of Technology (MIT)': [('100', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('90', 'International Students Ratio'), ('96.1', 'International Research Network'), ('100', 'Employment Outcomes')], 'University of Cambridge': [('98.8', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('92.3', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('96.3', 'International Students Ratio'), ('99.5', 'International Research Network'), ('100', 'Employment Outcomes')], 'Stanford University': [('98.5', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('99.9', 'Citations per Faculty'), ('99.8', 'International Faculty Ratio'), ('60.3', 'International Students Ratio'), ('96.3', 'International Research Network'), ('100', 'Employment Outcomes')], 'University of Oxford': [('98.4', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('90', 'Citations per Faculty'), ('98.8', 'International Faculty Ratio'), ('98.4', 'International Students Ratio'), ('99.9', 'International Research Network'), ('100', 'Employment Outcomes')], 'Harvard University': [('97.6', 'Overall'), ('100', 'Academic Reputation'), ('100', 'Employer Reputation'), ('99.4', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('76.9', 'International Faculty Ratio'), ('66.9', 'International Students Ratio'), ('100', 'International Research Network'), ('100', 'Employment Outcomes')], 'California Institute of Technology (Caltech)': [('97', 'Overall'), ('96.5', 'Academic Reputation'), ('87.1', 'Employer Reputation'), ('100', 'Faculty Student Ratio'), ('100', 'Citations per Faculty'), ('99.8', 'International Faculty Ratio'), ('85.1', 'International Students Ratio'), ('73', 'International Research Network'), ('98.8', 'Employment Outcomes')], 'Imperial College London': [('97', 'Overall'), ('98.3', 'Academic Reputation'), ('99.7', 'Employer Reputation'), ('99.5', 'Faculty Student Ratio'), ('86.5', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('100', 'International Students Ratio'), ('98.1', 'International Research Network'), ('88.8', 'Employment Outcomes')], 'UCL': [('95', 'Overall'), ('99.4', 'Academic Reputation'), ('98.6', 'Employer Reputation'), ('97.6', 'Faculty Student Ratio'), ('77', 'Citations per Faculty'), ('99.2', 'International Faculty Ratio'), ('100', 'International Students Ratio'), ('100', 'International Research Network'), ('90.3', 'Employment Outcomes')], 'ETH Zurich': [('93.6', 'Overall'), ('98.6', 'Academic Reputation'), ('91.3', 'Employer Reputation'), ('74.2', 'Faculty Student Ratio'), ('99.2', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('98', 'International Students Ratio'), ('96.2', 'International Research Network'), ('91.1', 'Employment Outcomes')], 'University of Chicago': [('93.2', 'Overall'), ('99.2', 'Academic Reputation'), ('92.2', 'Employer Reputation'), ('92.9', 'Faculty Student Ratio'), ('86.8', 'Citations per Faculty'), ('81.6', 'International Faculty Ratio'), ('76', 'International Students Ratio'), ('89.6', 'International Research Network'), ('98.2', 'Employment Outcomes')], 'National University of Singapore (NUS)': [('92.7', 'Overall'), ('99.5', 'Academic Reputation'), ('94.1', 'Employer Reputation'), ('79.8', 'Faculty Student Ratio'), ('91.8', 'Citations per Faculty'), ('100', 'International Faculty Ratio'), ('73.5', 'International Students Ratio'), ('89.9', 'International Research Network'), ('99.6', 'Employment Outcomes')], 'Peking University': [('91.3', 'Overall'), ('99.3', 'Academic Reputation'), ('96.5', 'Employer Reputation'), ('87.3', 'Faculty Student Ratio'), ('96.7', 'Citations per Faculty'), ('57.1', 'International Faculty Ratio'), ('36.9', 'Inter ...
# {'Massachusetts Institute of Technology (MIT)': [('Total students', '11,035'), ('International students', '3,627'), ('Total faculty staff', '2,919')], 'University of Cambridge': [('Total students', '20,871'), ('International students', '7,865'), ('Total faculty staff', '5,735')], 'Stanford University': [('Total students', '14,518'), ('International students', '3,318'), ('Total faculty staff', '4,694')], 'University of Oxford': [('Total students', '21,972'), ('International students', '9,024'), ('Total faculty staff', '6,650')], 'Harvard University': [('Total students', '21,877'), ('International students', '5,379'), ('Total faculty staff', '4,480')], 'California Institute of Technology (Caltech)': [('Total students', '2,240'), ('International students', '683'), ('Total faculty staff', '969')], 'Imperial College London': [('Total students', '20,191'), ('International students', '12,332'), ('Total faculty staff', '4,099')], 'UCL': [('Total students', '41,194'), ('International students', '25,076'), ('Total faculty staff', '7,251')], 'ETH Zurich': [('Total students', '20,892'), ('International students', '8,420'), ('Total faculty staff', '2,820')], 'University of Chicago': [('Total students', '16,325'), ('International students', '4,442'), ('Total faculty staff', '2,703')], 'National University of Singapore (NUS)': [('Total students', '30,725'), ('International students', '8,129'), ('Total faculty staff', '4,268')], 'Peking University': [('Total students', '31,873'), ('International students', '5,436'), ('Total faculty staff', '5,361')], 'University of Pennsylvania': [('Total students', '22,261'), ('International students', '5,426'), ('Total faculty staff', '5,069')], 'Tsinghua University': [('Total students', '36,893'), ('International students', '5,162'), ('Total faculty staff', '6,136')], 'The University of Edinburgh': [('Total students', '33,861'), ('International students', '15,268'), ('Total faculty staff', '4,865')], 'EPFL': [('Total students', '10,919'), ('International students', '6,837'), ('Total faculty staff', '1,757')], 'Princeton University': [('Total students', '7,767'), ('International students', '1,813'), ('Total faculty staff', '1,066')], 'Yale University': [('Total students', '11,283'), ('International students', '3,118'), ('Total faculty staff', '5,527')], 'Nanyang Technological University, Singapore (NTU Singapore)': [('Total students', '25,895'), ('International students', '6,900'), ('Total faculty staff', '3,735')], 'Cornell University': [('Total students', '23,188'), ('International students', '5,015'), ('Total faculty staff', '2,838')], 'The University of Hong Kong': [('Total students', '19,958'), ('International students', '8,353'), ('Total faculty staff', '2,957')], 'Columbia University': [('Total students', '25,914'), ('International students', '8,686'), ('Total faculty staff', '7,401')], 'The University of Tokyo': [('Total students', '27,826'), ('International students', '4,063'), ('Total faculty staff', '4,534')], 'Johns Hopkins University': [('Total students', '14,891'), ('International students', '4,251'), ('Total faculty staff', '4,969')], 'University of Michigan-Ann Arbor': [('Total students', '45,651'), ('International students', '7,341'), ('Total faculty staff', '7,132')], 'Université PSL': [('Total students', '14,591'), ('International students', '5,536'), ('Total faculty staff', '3,180')], 'University of California, Berkeley (UCB)': [('Total students', '40,468'), ('International students', '8,989'), ('Total faculty staff', '3,405')], 'The University of Manchester': [('Total students', '41,182'), ('International students', '18,345'), ('Total faculty staff', '4,829')], 'Seoul National University': [('Total students', '24,451'), ('International students', '2,014'), ('Total faculty staff', '3,838')], 'Australian National University (ANU)': [('Total students', '17,269'), ('International students', '6,152'), ('Total faculty staff', '1,716')], 'McGill University': [('Total students', '30,391'), ('In ...

# %% [markdown]
# Ниже обработаем показатели, чтобы их было удобно включить в датафрейм

# %%
feats_circles = {'name': []}

# %%
for i in map(lambda x: x[-1], circle_dict['Massachusetts Institute of Technology (MIT)']):
    feats_circles.setdefault(i, [])

# %%
for i in circle_dict:
    
    info = dict(map(lambda x: x[::-1],(circle_dict[i])))
    feats_circles['name'].append(i)
    for j in list(feats_circles)[1:]:
        feats_circles[j].append(info.get(j))

# %%
feats_circles
# Out:
# {'name': ['Massachusetts Institute of Technology (MIT)',
#   'University of Cambridge',
#   'Stanford University',
#   'University of Oxford',
#   'Harvard University',
#   'California Institute of Technology (Caltech)',
#   'Imperial College London',
#   'UCL',
#   'ETH Zurich',
#   'University of Chicago',
#   'National University of Singapore (NUS)',
#   'Peking University',
#   'University of Pennsylvania',
#   'Tsinghua University',
#   'The University of Edinburgh',
#   'EPFL',
#   'Princeton University',
#   'Yale University',
#   'Nanyang Technological University, Singapore (NTU Singapore)',
#   'Cornell University',
#   'The University of Hong Kong',
#   'Columbia University',
#   'The University of Tokyo',
#   'Johns Hopkins University',
#   'University of Michigan-Ann Arbor',
#   'Université PSL',
#   'University of California, Berkeley (UCB)',
#   'The University of Manchester',
#   'Seoul National University',
#   'Australian National University (ANU)',
#   'McGill University',
#   'Northwestern University',
#   'The University of Melbourne',
#   'Fudan University',
#   'University of Toronto',
#   'Kyoto University',
#   "King's College London",
#   'The Chinese University of Hong Kong (CUHK)',
#   'New York University (NYU)',
#   'The Hong Kong University of Science and Technology',
#   'The University of Sydney',
#   'KAIST - Korea Advanced Institute of Science & Technology',
#   'Zhejiang University',
#   'University of California, Los Angeles (UCLA)',
#   'The University of New South Wales (UNSW Sydney)',
#   'Shanghai Jiao Tong University',
#   'University of British Columbia',
#   'Institut Polytechnique de Paris',
#   'Technical University of Munich',
#   'Duke University'],
#  'Overall': ['100',
#   '98.8',
#   '98.5',
#   '98.4',
#   '97.6',
#   '97',
#   '97',
#   '95',
#   '93.6',
#   '93.2',
#   '92.7',
#   '91.3',
#   '90.6',
#   '90.1',
#   '89.5',
#   '89.2',
#   '89.2',
#   '89',
#   '88.4',
#   '87.2',
#   '87',
#   '86.7',
#   '85.3',
#   '85.1',
#   '84.4',
#   '83.8',
#   '82.7',
#   '82.3',
#   '82.2',
#   '82.1',
#   '81.9',
#   '81.8',
#   '81.6',
#   '81.5',
#   '81.5',
#   '81.4',
#   '81.2',
#   '80.6',
#   '80.3',
#   '79.8',
#   '79.6',
#   '79.3',
#   '79.3',
#   '78.7',
#   '78',
#   '77.4',
#   '77',
#   '76.8',
#   '76.4',
#   '74.8'],
#  'Academic Reputation': ['100',
#   '100',
#   '100',
#   '100',
#   '100',
#   '96.5',
#   '98.3',
#   '99.4',
#   '98.6',
#   '99.2',
#   '99.5',
#   '99.3',
#   '96.5',
#   '98.9',
#   '98',
#   '83.7',
#   '99.9',
#   '99.9',
#   '90.4',
#   '98.3',
#   '97.4',
#   '99.7',
#   '100',
#   '87.9',
#   '98.5',
#   '74.4',
#   '100',
#   '95.1',
#   '98.6',
#   '93.6',
#   '93.3',
#   '84.4',
#   '98.6',
#   '83.6',
#   '99.6',
#   '98.6',
#   '88.8',
#   '87.3',
#   '95.9',
#   '82',
#   '96.2',
#   '88.1',
#   '72.2',
#   '100',
#   '89',
#   '82.7',
#   '98',
#   '45.3',
#   '84',
#   '86.1'],
#  'Employer Reputation': ['100',
#   '100',
#   '100',
#   '100',
#   '100',
#   '87.1',
#   '99.7',
#   '98.6',
#   '91.3',
#   '92.2',
#   '94.1',
#   '96.5',
#   '92.5',
#   '97.7',
#   '97.2',
#   '71.8',
#   '98.9',
#   '100',
#   '76.1',
#   '91.4',
#   '62.9',
#   '98.1',
#   '99.7',
#   '47.2',
#   '91.3',
#   '97',
#   '100',
#   '97.7',
#   '97.8',
#   '70.1',
#   '93.6',
#   '71.9',
#   '94.9',
#   '93.5',
#   '98.3',
#   '98.9',
#   '83.2',
#   '49.6',
#   '99',
#   '50.1',
#   '91.7',
#   '85.8',
#   '95.3',
#   '99.9',
#   '91.1',
#   '90.2',
#   '95.4',
#   '99.4',
#   '96.8',
#   '79.8'],
#  'Faculty Student Ratio': ['100',
#   '100',
#   '100',
#   '100',
#   '99.4',
#   '100',
#   '99.5',
#   '97.6',
#   '74.2',
#   '92.9',
#   '79.8',
#   '87.3',
#   '99.9',
#   '92.8',
#   '81.1',
#   '91.1',
#   '72.6',
#   '100',
#   '83.2',
#   '62.2',
#   '84.2',
#   '100',
#   '91.9',
#   '100',
#   '88.9',
#   '99.8',
#   '23.9',
#   '63.1',
#   '87',
#   '38',
#   '68.9',
#   '98.3',
#   '17.9',
#   '89.3',
#   '65.6',
#   '94.8',
#   '74.5',
#   '60.9',
#   '98.1',
#   '62.6',
#   '15.6',
#   '68.9',
#   '78.7',
#   '37.7',
#   '16.8',
#   '57.7',
#   '56.5',
#   '98.9',
#   '96.4',
#   '100'],
#  'Citations per Faculty': ['100',
#   '92.3',
#   '99.9',
#   '90',
#   '100',
#   '100',
#   '86.5',
#   '77',
#   '99.2',
#   '86.8',
#   '91.8',
#   '96.7',
#   '70.9',
#   '98.1',
#   '70.1',
#   '99.4',
#   '100',
#   '51.5',
#   '94.1',
#   '99.3',
#   '72.6',
#   '47.2',
#   '73.3',
#   '87.3',
#   '62.5',
#   '84.1',
#   '99.9',
#   '59',
#   '70.3',
#   '99.3',
#   '59.6',
#   '84.2',
#   '95',
#   '70.4',
#   '43.5',
#   '54.2',
#   '60.5',
#   '92.9',
#   '28.9',
#   '98.6',
#   '92.1',
#   '97.7',
#   '88.4',
#   '85.9',
#   '97.6',
#   '97.1',
#   '42.1',
#   '93.9',
#   '25.8',
#   '41.2'],
#  'International Faculty Ratio': ['100',
#   '100',
#   '99.8',
#   '98.8',
#   '76.9',
#   '99.8',
#   '100',
#   '99.2',
#   '100',
#   '81.6',
#   '100',
#   '57.1',
#   '96.2',
#   '16.7',
#   '98.9',
#   '100',
#   '26',
#   '89.2',
#   '100',
#   '63.9',
#   '100',
#   '47.6',
#   '10.4',
#   '63.6',
#   '71.2',
#   '59.7',
#   '93.3',
#   '93.4',
#   '12.2',
#   '100',
#   '87.6',
#   '40.5',
#   '93.1',
#   '89.3',
#   '95.8',
#   '14.9',
#   '98.6',
#   '100',
#   '31.3',
#   '100',
#   '99.3',
#   '23.1',
#   '99.1',
#   '45.1',
#   '100',
#   '40.9',
#   '89',
#   '97',
#   '70.3',
#   '20.2'],
#  'International Students Ratio': ['90',
#   '96.3',
#   '60.3',
#   '98.4',
#   '66.9',
#   '85.1',
#   '100',
#   '100',
#   '98',
#   '76',
#   '73.5',
#   '36.9',
#   '66.1',
#   '25.7',
#   '99.5',
#   '100',
#   '62.2',
#   '77.3',
#   '74.1',
#   '55.3',
#   '98.7',
#   '94.6',
#   '27.8',
#   '82.9',
#   '33.1',
#   '83.6',
#   '57.7',
#   '99.4',
#   '10.3',
#   '96',
#   '95.1',
#   '38.8',
#   '99.8',
#   '38.7',
#   '95.7',
#   '22.1',
#   '100',
#   '90.5',
#   '94.4',
#   '87.9',
#   '100',
#   '12.3',
#   '42.5',
#   '27.5',
#   '99.8',
#   '38.4',
#   '74.9',
#   '98.2',
#   '95',
#   '55.1'],
#  'International Research Network': ['96.1',
#   '99.5',
#   '96.3',
#   '99.9',
#   '100',
#   '73',
#   '98.1',
#   '100',
#   '96.2',
#   '89.6',
#   '89.9',
#   '77.5',
#   '93.3',
#   '75.5',
#   '98.7',
#   '87.3',
#   '78.5',
#   '92',
#   '89.6',
#   '90',
#   '81.1',
#   '98.9',
#   '89.5',
#   '97.7',
#   '96.3',
#   '99.7',
#   '96.7',
#   '98.9',
#   '79.3',
#   '94.6',
#   '95.2',
#   '89',
#   '97.6',
#   '70.6',
#   '96.7',
#   '85.5',
#   '99.3',
#   '74.9',
#   '92',
#   '56.2',
#   '97.3',
#   '65.2',
#   '80.8',
#   '96.3',
#   '98.2',
#   '73.9',
#   '97.9',
#   '94.8',
#   '91.8',
#   '95.5'],
#  'Employment Outcomes': ['100',
#   '100',
#   '100',
#   '100',
#   '100',
#   '98.8',
#   '88.8',
#   '90.3',
#   '91.1',
#   '98.2',
#   '99.6',
#   '91.4',
#   '100',
#   '87.1',
#   '54.3',
#   '28',
#   '100',
#   '100',
#   '84.6',
#   '99.5',
#   '99',
#   '99.8',
#   '97.8',
#   '95.3',
#   '96',
#   '53.9',
#   '99.1',
#   '66.4',
#   '97.7',
#   '59.1',
#   '90',
#   '98.4',
#   '91.1',
#   '65.7',
#   '94',
#   '56.9',
#   '56.9',
#   '79.4',
#   '99.7',
#   '91.2',
#   '90.8',
#   '63.2',
#   '42.3',
#   '98',
#   '93',
#   '57.8',
#   '75.2',
#   '99.8',
#   '37.5',
#   '98.6']}

# %% [markdown]
# Тут обработаем количество студентов и преподавателей

# %%
feats_studs = {'name': []}

# %%
for i in map(lambda x: x[0], student_stats_dict['Massachusetts Institute of Technology (MIT)']):
    feats_studs.setdefault(i, [])

# %%
for i in student_stats_dict:
    
    info = dict(student_stats_dict[i])
    feats_studs['name'].append(i)
    for j in list(feats_studs)[1:]:
        feats_studs[j].append(info.get(j))

# %%
circle_df = pd.DataFrame(feats_circles)

# %%
stud_df = pd.DataFrame(feats_studs)

# %% [markdown]
# Начинаем объединение в единый датафрейм

# %%
prefinal = data.merge(stud_df, left_on = 'name', right_on =  'name')

# %%
final = prefinal.merge(circle_df, left_on = 'name', right_on = 'name')

# %%
final['rank'] = final['rank'].str.extract('(\d+)', expand=False)

# %%
final
# Out:
#    rank                                               name  \
# 0     1        Massachusetts Institute of Technology (MIT)
# 1     2                            University of Cambridge
# 2     3                                Stanford University
# 3     4                               University of Oxford
# 4     5                                 Harvard University
# 5     6       California Institute of Technology (Caltech)
# 6     6                            Imperial College London
# 7     8                                                UCL
# 8     9                                         ETH Zurich
# 9    10                              University of Chicago
# 10   11             National University of Singapore (NUS)
# 11   12                                  Peking University
# 12   13                         University of Pennsylvania
# 13   14                                Tsinghua University
# 14   15                        The University of Edinburgh
# 15   16                                               EPFL
# 16   16                               Princeton University
# 17   18                                    Yale University
# 18   19  Nanyang Technological University, Singapore (N...
# 19   20                                 Cornell University
# 20   21                        The University of Hong Kong
# 21   22                                Columbia University
# 22   23                            The University of Tokyo
# 4                4,480    97.6                 100                 100
# 5                  969      97                96.5                87.1
# 6                4,099      97                98.3                99.7
# 7                7,251      95                99.4                98.6
# 8                2,820    93.6                98.6                91.3
# 9                2,703    93.2                99.2                92.2
# 10               4,268    92.7                99.5                94.1
# 11               5,361    91.3                99.3                96.5
# 12               5,069    90.6                96.5                92.5
# 13               6,136    90.1                98.9                97.7
# 14               4,865    89.5                  98                97.2
# 15               1,757    89.2                83.7                71.8
# 16               1,066    89.2                99.9                98.9
# 17               5,527      89                99.9                 100
# 18               3,735    88.4                90.4                76.1
# 19               2,838    87.2                98.3                91.4
# 20               2,957      87                97.4                62.9
# 21               7,401    86.7                99.7                98.1
# 22               4,534    85.3                 100                99.7
# 23               4,969    85.1                87.9                47.2
# 24               7,132    84.4                98.5                91.3
# 25               3,180    83.8                74.4                  97
# 26               3,405    82.7                 100                 100
# 27               4,829    82.3                95.1                97.7
# 28               3,838    82.2                98.6                97.8
# 29               1,716    82.1                93.6                70.1
# 30               3,926    81.9                93.3                93.6
# 31               3,579    81.8                84.4                71.9
# 32               3,668    81.6                98.6                94.9
# 33               4,771    81.5                83.6                93.5
# 34              10,191    81.5                99.6                98.3
# 35               3,863    81.4                98.6                98.9
# 36               4,027    81.2                88.8                83.2
# 37               2,217    80.6                87.3                49.6
# 38               7,386    80.3                95.9                  99
# 39               1,176    79.8                  82                50.1
# 40               3,297    79.6                96.2                91.7
# 41               1,289    79.3                88.1                85.8
# 42               5,084    79.3                72.2                95.3
# 43               4,532    78.7                 100                99.9
# 44               3,149      78                  89                91.1
# 45               4,492    77.4                82.7                90.2
# 46               6,269      77                  98                95.4
# 47               1,148    76.8                45.3                99.4
# 48               6,855    76.4                  84                96.8
# 49               5,608    74.8                86.1                79.8
#
#    Faculty Student Ratio Citations per Faculty International Faculty Ratio  \
# 0                    100                   100                         100
# 1                    100                  92.3                         100
# 2                    100                  99.9                        99.8
# 3                    100                    90                        98.8
# 4                   99.4                   100                        76.9
# 5                    100                   100                        99.8
# 6                   99.5                  86.5                         100
# 7                   97.6                    77                        99.2
# 8                   74.2                  99.2                         100
# 9                   92.9                  86.8                        81.6
# 10                  79.8                  91.8                         100
# 11                  87.3                  96.7                        57.1
# 12                  99.9                  70.9                        96.2
# 13                  92.8                  98.1                        16.7
# 14                  81.1                  70.1                        98.9
# 15                  91.1                  99.4                         100
# 16                  72.6                   100                          26
# 17                   100                  51.5                        89.2
# 18                  83.2                  94.1                         100
# 19                  62.2                  99.3                        63.9
# 20                  84.2                  72.6                         100
# 21                   100                  47.2                        47.6
# 22                  91.9                  73.3                        10.4
# 23                   100                  87.3                        63.6
# 24                  88.9                  62.5                        71.2
# 25                  99.8                  84.1                        59.7
# 26                  23.9                  99.9                        93.3
# 27                  63.1                    59                        93.4
# 28                    87                  70.3                        12.2
# 29                    38                  99.3                         100
# 30                  68.9                  59.6                        87.6
# 31                  98.3                  84.2                        40.5
# 32                  17.9                    95                        93.1
# 33                  89.3                  70.4                        89.3
# 34                  65.6                  43.5                        95.8
# 35                  94.8                  54.2                        14.9
# 36                  74.5                  60.5                        98.6
# 37                  60.9                  92.9                         100
# 38                  98.1                  28.9                        31.3
# 39                  62.6                  98.6                         100
# 40                  15.6                  92.1                        99.3
# 41                  68.9                  97.7                        23.1
# 42                  78.7                  88.4                        99.1
# 43                  37.7                  85.9                        45.1
# 44                  16.8                  97.6                         100
# 45                  57.7                  97.1                        40.9
# 46                  56.5                  42.1                          89
# 47                  98.9                  93.9                          97
# 48                  96.4                  25.8                        70.3
# 49                   100                  41.2                        20.2
#
#    International Students Ratio International Research Network  \
# 0                            90                           96.1
# 1                          96.3                           99.5
# 2                          60.3                           96.3
# 3                          98.4                           99.9
# 4                          66.9                            100
# 5                          85.1                             73
# 6                           100                           98.1
# 7                           100                            100
# 8                            98                           96.2
# 9                            76                           89.6
# 10                         73.5                           89.9
# 11                         36.9                           77.5
# 12                         66.1                           93.3
# 13                         25.7                           75.5
# 14                         99.5                           98.7
# 15                          100                           87.3
# 16                         62.2                           78.5
# 17                         77.3                             92
# 18                         74.1                           89.6
# 19                         55.3                             90
# 20                         98.7                           81.1
# 21                         94.6                           98.9
# 22                         27.8                           89.5
# 23                         82.9                           97.7
# 24                         33.1                           96.3
# 25                         83.6                           99.7
# 26                         57.7                           96.7
# 27                         99.4                           98.9
# 28                         10.3                           79.3
# 29                           96                           94.6
# 30                         95.1                           95.2
# 31                         38.8                             89
# 32                         99.8                           97.6
# 33                         38.7                           70.6
# 34                         95.7                           96.7
# 35                         22.1                           85.5
# 36                          100                           99.3
# 37                         90.5                           74.9
# 38                         94.4                             92
# 39                         87.9                           56.2
# 40                          100                           97.3
# 41                         12.3                           65.2
# 42                         42.5                           80.8
# 43                         27.5                           96.3
# 44                         99.8                           98.2
# 45                         38.4                           73.9
# 46                         74.9                           97.9
# 47                         98.2                           94.8
# 48                           95                           91.8
# 49                         55.1                           95.5
#
#    Employment Outcomes
# 0                  100
# 1                  100
# 2                  100
# 3                  100
# 4                  100
# 5                 98.8
# 6                 88.8
# 7                 90.3
# 8                 91.1
# 9                 98.2
# 10                99.6
# 11                91.4
# 12                 100
# 13                87.1
# 14                54.3
# 15                  28
# 16                 100
# 17                 100
# 18                84.6
# 19                99.5
# 20                  99
# 21                99.8
# 22                97.8
# 23                95.3
# 24                  96
# 25                53.9
# 26                99.1
# 27                66.4
# 28                97.7
# 29                59.1
# 30                  90
# 31                98.4
# 32                91.1
# 33                65.7
# 34                  94
# 35                56.9
# 36                56.9
# 37                79.4
# 38                99.7
# 39                91.2
# 40                90.8
# 41                63.2
# 42                42.3
# 43                  98
# 44                  93
# 45                57.8
# 46                75.2
# 47                99.8
# 48                37.5
# 49                98.6

# %% [markdown]
# Вот и получили наш красивый датафрейм. У проверяющего может быть резонный вопрос: почему нужно было показывать на примере, если сразу после парсинга данных вы все преобразовали в датафрейм? Объясняю - все было крайне запутано, в юпитерском файле был полнейший беспорядок и вместо того, чтобы разбираться в этом беспорядке, решил показать на маленьком примере.
